# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df =  pd.read_csv("C:\\Data Science\\Data Science Nareshit\\EDA datasets\\visadataset.csv")
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sns.scatterplot(x="continent",y="yr_of_estab",data=df)
plt.title("Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
#line plot
sns.lineplot(x="continent",y="yr_of_estab",data=df)
plt.title("line plot")
plt.show()

# %%
#categorical plot
#barplot
sns.barplot(x='prevailing_wage',y='no_of_employee',data=df)
plt.title("bar plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 #categorical plot
#       2 #barplot
# ----> 3 sns.barplot(x='prevailing_wage',y='no_of_employee',data=df)
#       4 plt.title("bar plot")
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
# ...

# %%
#box plot
sns.boxplot(x="prevailing_wage",y="case_status",data=df)
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='case_status'>

# %%
#histogram
sns.histplot(df['continent'],bins=50,kde=True)
# Out:
# <Axes: xlabel='continent', ylabel='Count'>

# %%
#kde plot
sns.kdeplot(df['continent'],shade=True)
# Out:
# C:\Users\tharu\AppData\Local\Temp\ipykernel_17680\3564589991.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['continent'],shade=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #kde plot
# ----> 2 sns.kdeplot(df['continent'],shade=True)
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='continent',y='prevailing_wage',data=df)
